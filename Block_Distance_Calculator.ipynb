# %%
#@title Block Distance Calculator
#made by chairpop
PixelWidth = float(1)
ScreenWidth = float(1)
HeightAnswer = float(1)
WidthAnswer = float(1)
PixelHeight = float(1)
ScreenHeight = float(1)
WAnswer = float(1)
HAnswer = float(1)
WNum1 = float(0.08)
WNum2 = float(0.04)
WNum3 = float(0.025)
WNum4 = float(0.2)
WNum5 = float(0.016)
WNum6 = float(0.013)
WNum7 = float(0.012)
WNum8 = float(0.007)
WNum9 = float(0.006)
WNum10 = float(0.004)
HNum1 = float(0.15)
HNum2 = float(0.075)
HNum3 = float(0.045)
HNum4 = float(0.35)
HNum5 = float(0.028)
HNum6 = float(0.024)
HNum7 = float(0.021)
HNum8 = float(0.013)
HNum9 = float(0.01)
HNum10 = float(0.007)


Choice = input("Do you want to use block width or block height? Enter 1 for Width and 2 for Height: ")

if Choice == "1":
  PixelWidth = input("Enter Block Width: ")
  ScreenWidth = input("Enter Screen Width: ")
  PixelWidth = float(PixelWidth)
  ScreenWidth = float(ScreenWidth)
  WidthAnswer = PixelWidth / ScreenWidth
  WidthAnswer = float(WidthAnswer)
  if WidthAnswer >= WNum1: 
    WAnswer = (-4.57 * WidthAnswer + 4.3)
    print("1-5")
    print(WAnswer)
  elif WidthAnswer >= WNum2:
    WAnswer = (-129 * WidthAnswer + 15.1)
    print("6-10")
    print(WAnswer)
  elif WidthAnswer >= WNum3: 
    WAnswer = (-400 * WidthAnswer  + 26.2)
    print("11-16")
    print(WAnswer)
  elif WidthAnswer >= WNum4:
    WAnswer = (-960 * WidthAnswer + 40)
    print("17-20")
    print(WAnswer)
  elif WidthAnswer >= WNum5:
    WAnswer = (-1129 * WidthAnswer + 43.2)
    print("21-25")
    print(WAnswer)
  elif WidthAnswer >= WNum6:
    WAnswer = (-1920 * WidthAnswer + 56.5)
    print("26-31")
    print(WAnswer)
  elif WidthAnswer >= WNum7:
    WAnswer = (33)
    print("32-34")
    print(WAnswer)
  elif WidthAnswer >= WNum8:
    WAnswer = (-4800 * WidthAnswer + 90)
    print("35-56")
    print(WAnswer)
  elif WidthAnswer >= WNum9:
    WAnswer = (-7200 * WidthAnswer + 110)
    print("57-70")
    print(WAnswer)
  elif WidthAnswer >= WNum10:
    WAnswer = (-9600 * WidthAnswer + 130)
    print("71-100")
    print(WAnswer)
  elif WidthAnswer < WNum10:
    print("Block is further than 100 blocks away.")

if Choice == "2":
  PixelHeight = input("Enter Block Height: ")
  ScreenHeight = input("Enter Screen Height: ")
  PixelHeight = float(PixelHeight)
  ScreenHeight = float(ScreenHeight)
  HeightAnswer = PixelHeight / ScreenHeight
  HeightAnswer = float(HeightAnswer)
  if HeightAnswer >= HNum1:
    HAnswer = (-8.77 * HAnswer + 5.97)
    print("1-5")
    print(HAnswer)
  elif HeightAnswer >= HNum2:
    HAnswer = (-71.7 * HeightAnswer + 15.1)
    print("6-10")
    print(HAnswer)
  elif HeightAnswer >= HNum3: 
    HAnswer = (-222 * HeightAnswer + 25.9)
    print("11-16")
    print(HAnswer)
  elif HeightAnswer >= HNum4:
    HAnswer = (-464 * HeightAnswer + 37.1)
    print("17-20")
    print(HAnswer)
  elif HeightAnswer >= HNum5:
    HAnswer = (-727 * HeightAnswer + 46)
    print("21-25")
    print(HAnswer)
  elif HeightAnswer >= HNum6:
    HAnswer = (-1215 * HeightAnswer + 59.6)
    print("26-31")
    print(HAnswer)
  elif HeightAnswer >= HNum7:
    HAnswer = (-1620 * HeightAnswer + 68.5)
    print("32-34")
    print(HAnswer)
  elif HeightAnswer >= HNum8:
    HAnswer = (-3058 * HeightAnswer + 95.8)
    print("35-56")
    print(HAnswer)
  elif HeightAnswer >= HNum9:
    HAnswer = (-5400 * HeightAnswer + 125)
    print("57-70")
    print(HAnswer)
  elif HeightAnswer >= HNum10:
    HAnswer = (-8800 * HeightAnswer + 160)
    print("71-100")
    print(HAnswer)
  elif HeightAnswer < HNum10:
    print("Block is further than 100 blocks away.")
